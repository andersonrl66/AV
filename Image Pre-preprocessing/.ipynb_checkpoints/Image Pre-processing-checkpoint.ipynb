# %%
# read image
#import imageio
#import visvis as vv
#image = imageio.imread("/home/lemos/Cursos/a-comprehensive-learning-path-for-deep-learning-in-2019/Image Pre-preprocessing/florMenor.JPG")
#print(image.shape)
#vv.imshow(image)
import cv2
import matplotlib.pyplot as plt

im = cv2.imread('/home/lemos/Cursos/a-comprehensive-learning-path-for-deep-learning-in-2019/Image Pre-preprocessing/florMenor.JPG')
im_resized = cv2.resize(im, (224, 224), interpolation=cv2.INTER_LINEAR)

plt.imshow(cv2.cvtColor(im_resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# show images side by side
import matplotlib.pyplot as plt
import numpy as np

def show_images(images,titles=None):
    """Display a list of images"""
    n_ims = len(images)
    if titles is None: titles = ['(%d)' % i for i in range(1,n_ims + 1)]
    fig = plt.figure()
    n = 1
    for image,title in zip(images,titles):
        a = fig.add_subplot(1,n_ims,n) # Make subplot
        if image.ndim == 2: # Is image grayscale?
            plt.gray() # Only place in this blog you can't replace 'gray' with 'grey'
        plt.imshow(image)
        a.set_title(title)
        n += 1
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_ims)
    plt.show()

# %%
# gray scale
from skimage.color import rgb2gray
gray_image = rgb2gray(im)
show_images(images=[im,gray_image],titles=["Color","Grayscale"])
print ("Colored image shape:", im.shape)
print ("Grayscale image shape:", gray_image.shape)
# Out:
# Colored image shape: (3888, 5184, 3)
# Grayscale image shape: (3888, 5184)

# %%
# blur the image
from skimage.filters import gaussian
blurred_image = gaussian(gray_image,sigma=30)
show_images(images=[gray_image,blurred_image],titles=["Gray Image","30 Sigma Blur"])

# %%
# binary
from skimage.filters import threshold_otsu
thresh = threshold_otsu(gray_image)
binary_image = gray_image > thresh
show_images(images=[gray_image,binary_image,binary],titles=["Grayscale","Otsu Binary"])

# %%
# intensity
red, green, blue, yellow =   im.copy(), im.copy(), im.copy(), im.copy()
red[:,:,(1,2)] = 0
green[:,:,(0,2)] = 0
blue[:,:,(0,1)] = 0
yellow[:,:,2]=0
show_images(images=[red, green, blue, yellow], titles=['Red Intensity','Green Intensity','Blue Intensity','Yellow Intensity'])
